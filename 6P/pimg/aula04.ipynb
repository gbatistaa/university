# %%
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt

# %%
mama = imread('mamografia.png')

# %%
plt.imshow(mama,cmap='gray')

# %%
h,_ = np.histogram(mama,bins=256)

# %%
plt.plot(h,'-k')

# %%
aeroporto = imread('aeroporto.png')
# Out:
# Bad pipe message: %s [b' x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36\r\nAccept: text/html,application/xhtml+']
# Bad pipe message: %s [b'l,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8\r\nAccept-Encoding: gzip, deflate, br, zstd\r\nAccept-La', b'uage: en-US,en;q=0.5\r\nConnection: keep-alive\r\nReferer: https://studio.firebase.google.com/\r\nSec-Ch-Ua: "Brave', b'v="141", "Not?A_Brand";v="8", "Ch', b'mium";v="141"\r\nSec-Ch-Ua-Arch: "x86"\r\nSec-Ch-Ua-Bitness: "64"\r\nSec-Ch-Ua-Full-Version-List: "Brave";v="141.0.0.0"', b'"Not?A_Brand";v="8.0.0.0", "Chromium";v="14']
# Bad pipe message: %s [b'0.0.0"\r\nSec-Ch-Ua-Mobile: ?0\r\nSec-Ch-Ua-Model: "']
# Bad pipe message: %s [b'\nSec-Ch-Ua-Platform: "Linux"\r\nSec', b'h-Ua-Platform-Version: ""\r\nSec-Ch-Ua-Wow64: ', b'\r\nSec-Fetch-Dest: iframe\r\nSec-Fetch-Mode: navigate\r\nSec-Fetch-']
# Bad pipe message: %s [b'te: cross-site\r\nSec-Fetch-Storage-Access: none\r\nSec-Gpc: 1\r\nSec-User-Ip: 10.20.20.', b'5\r\nUpgrade-Insecure-Requests: 1\r\nX-Forwarded-Host']
# Bad pipe message: %s [b'44871-firebase-university-1760041075840.cluster-lr6dwlc2l']
# Bad pipe message: %s [b'cctqhqorax5zmro.cloudworkstations.dev\r\nX-Goog-Workstations-Endpoint: workstations-526e4078-7594-4b2b-b0ed-43a7bffbeebc.us']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 aeroporto = imread('aeroporto.png')
#
# File ~/university/.venv/lib/python3.11/site-packages/skimage/_shared/utils.py:328, in deprecate_parameter.__call__.<locals>.fixed_func(*args, **kwargs)
#     324     elif self.new_name is not None:
#     325         # Assign old value to new one
#     326         kwargs[self.new_name] = deprecated_value
# --> 328 return func(*args, **kwargs)
#
# File ~/university/.venv/lib/python3.11/site-packages/skimage/io/_io.py:82, in imread(fname, as_gray, plugin, **plugin_args)
#      79         plugin = 'tifffile'
#      81 with file_or_url_context(fname) as fname, _hide_plugin_deprecation_warnings():
# ---> 82     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      84 if not hasattr(img, 'ndim'):
#      85     return img
#
# File ~/university/.venv/lib/python3.11/site-packages/skimage/_shared/utils.py:538, in deprecate_func.__call__.<locals>.wrapped(*args, **kwargs)
#     536 stacklevel = 1 + self.get_stack_length(func) - stack_rank
#     537 warnings.warn(message, category=FutureWarning, stacklevel=stacklevel)
# --> 538 return func(*args, **kwargs)
#
# File ~/university/.venv/lib/python3.11/site-packages/skimage/io/manage_plugins.py:254, in call_plugin(kind, *args, **kwargs)
#     251     except IndexError:
#     252         raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
# --> 254 return func(*args, **kwargs)
#
# File ~/university/.venv/lib/python3.11/site-packages/skimage/io/_plugins/imageio_plugin.py:11, in imread(*args, **kwargs)
#       9 @wraps(imageio_imread)
#      10 def imread(*args, **kwargs):
# ---> 11     out = np.asarray(imageio_imread(*args, **kwargs))
#      12     if not out.flags['WRITEABLE']:
#      13         out = out.copy()
#
# File ~/university/.venv/lib/python3.11/site-packages/imageio/v3.py:53, in imread(uri, index, plugin, extension, format_hint, **kwargs)
#      50 if index is not None:
#      51     call_kwargs["index"] = index
# ---> 53 with imopen(uri, "r", **plugin_kwargs) as img_file:
#      54     return np.asarray(img_file.read(**call_kwargs))
#
# File ~/university/.venv/lib/python3.11/site-packages/imageio/core/imopen.py:113, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111     request.format_hint = format_hint
#     112 else:
# --> 113     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     115 source = "<bytes>" if isinstance(uri, bytes) else uri
#     117 # fast-path based on plugin
#     118 # (except in legacy mode)
#
# File ~/university/.venv/lib/python3.11/site-packages/imageio/core/request.py:249, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     246     raise ValueError(f"Invalid Request.Mode: {mode}")
#     248 # Parse what was given
# --> 249 self._parse_uri(uri)
#     251 # Set extension
#     252 if extension is not None:
#
# File ~/university/.venv/lib/python3.11/site-packages/imageio/core/request.py:409, in Request._parse_uri(self, uri)
#     406 if is_read_request:
#     407     # Reading: check that the file exists (but is allowed a dir)
#     408     if not os.path.exists(fn):
# --> 409         raise FileNotFoundError("No such file: '%s'" % fn)
#     410 else:
#     411     # Writing: check that the directory to write to does exist
#     412     dn = os.path.dirname(fn)
#
# FileNotFoundError: No such file: '/home/user/university/6P/pimg/aeroporto.png'

# %%
h,_ = np.histogram (aeroporto,256)
plt.plot (h,'-k')

# %%
plt.imshow(aeroporto,cmap='gray')

# %%
mama2 = 255 - mama
plt.imshow(mama2,cmap='gray')

# %%
h,_ = np.histogram (mama2,256)
plt.plot (h,'-k')

# %%
carro = imread ('HI00008918.png',as_gray=True)

# %%
carro = carro * 255
carro = carro.astype ('int')

# %%
plt.imshow (carro,cmap='gray')

# %%
h,_ = np.histogram (carro,256)
plt.plot (h,'-k')

# %%
carro2 = carro*2.5
carro2[carro2>250] = 255
carro2 = carro2.astype('int')

# %%
h,_ = np.histogram (carro2,256)
plt.plot (h,'-k')

# %%
plt.imshow(carro2,cmap='gray')

# %% [markdown]
# A operação anterior realizou o espalhamento do histograma nas regiões onde havia mais massa e, a compressão, nas regiões onde havia pouca. Isto  produziu o realce de contraste desejado. Há, no entanto, uma função que tem o mesmo efeito e não requer a inspeção manual do histograma. Esta é a função de probabilidade acumulada e é obtida pela equalização do histograma.
