# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread

# %%
taylor = imread('midnights-4k.png')

# %%
plt.imshow(taylor, cmap="gray")

# %%
taylor.shape
# Out:
# (992, 1056, 3)

# %%
taylow_r0 = taylor[400, :, 0]
taylow_r1 = taylor[700, :, 1]
taylow_r2 = taylor[580, :, 2]

# %%
plt.plot(taylow_r0)
plt.plot(taylow_r1)
plt.plot(taylow_r2)
